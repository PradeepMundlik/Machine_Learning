# %% [markdown]
# ## Pandas Tutorial

# %% [markdown]
# ### Creating Dataframes

# %% [markdown]
# ##### DataFrame is the central data structure for holding 2-dimensional rectangular data.

# %%
import pandas as pd

# %%
dict = {'ca': [35, 37, 38], 'tx': [23, 24, 26], 'md': [5,5,6]}
pop = pd.DataFrame(dict)
pop
# Out:
#    ca  tx  md
# 0  35  23   5
# 1  37  24   5
# 2  38  26   6

# %%
df = pd.read_excel("/home/pradeep/Documents/IITH Academics/FOML/ML_Codes/Set-2/LSVT_voice_rehabilitation.xlsx") 
df
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0              0.088112                0.041697
# 1              0.161798                0.057364
# 2              0.554508                0.642913
# 3              0.031089                0.027108
# 4              0.076177                0.039071
# ..                  ...                     ...
# 121            0.116214                0.070546
# 122            0.700258                0.334397
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                               0.000480                   -3.723304e-06
# 1                               0.000677                    5.466365e-06
# 2                               0.007576                   -7.443871e-07
# 3                               0.000314                   -2.214722e-07
# ...

# %%
df.head(3) #first 3 rows
# Out:
#    Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0            0.088112                0.041697
# 1            0.161798                0.057364
# 2            0.554508                0.642913
#
#    Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                             0.000480                   -3.723304e-06
# 1                             0.000677                    5.466365e-06
# 2                             0.007576                   -7.443871e-07
#
#    Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                               0.000422                   2.458381
# 1                               0.000206                   2.592066
# 2                               0.006488                  12.691326
#
#    Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0   6.332164e-07             47.021079          1366.430390
# 1   7.228518e-07             93.557936          2582.922776
# ...

# %%
df.tail(3) #last 3 rows
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 123                             0.000597                       -0.000005
# 124                             0.000646                       -0.000002
# 125                             0.001576                        0.000002
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 123                               0.000434                   6.984651
# 124                               0.000277                   1.935398
# 125                               0.000708                   2.339807
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 123   4.993260e-07             21.859427           625.288493
# 124   4.398078e-07             47.870508          1367.843467
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Columns: 310 entries, Jitter->F0_abs_dif to det_TKEO_std4_10_coef
# dtypes: float64(309), int64(1)
# memory usage: 305.3 KB

# %%
import matplotlib.pyplot as plt

# %%
ls = list(df.columns)
ls[:3]
# Out:
# ['Jitter->F0_abs_dif',
#  'Jitter->F0_dif_percent',
#  'Jitter->F0_PQ5_classical_Schoentgen']

# %%
df[ls[:3]].plot()
# Out:
# <AxesSubplot:>

# %%
df[ls[:3]].plot(kind='scatter',x=ls[1],y=ls[2])
# Out:
# <AxesSubplot:xlabel='Jitter->F0_dif_percent', ylabel='Jitter->F0_PQ5_classical_Schoentgen'>

# %%
df[ls[0]].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
